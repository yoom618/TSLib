# %% [markdown]
# # testing

# %%
# !python ../run.py \
    --use_gpu True \
    --gpu_type cuda \
    --gpu 2 \
    --task_name classification \
    --data UEA \
    --root_path /data/yoom618/TSLib/dataset/AtrialFibrillation/ \
    --seq_len 78 --enc_in 200 --label_len 0 --pred_len 0 --c_out 0 \
    --checkpoints /data/yoom618/TSLib/checkpoints \
    --model MTSMixer \
    --model_id TV_CLS_AtrialFibrillation \
    --e_layers 1 --d_model 64 --d_ff 16 --fac_T False --fac_C False \
    --down_sampling_window 13 --use_norm 0 --use_revin True --is_training 1 --batch_size 16 \
    --des Exp --itr 1 --dropout 0.1 --learning_rate 0.001 --weight_decay 0.0001 --train_epochs 200 --patience 20
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           TV_CLS_AtrialFibrillationModel:              MTSMixer
#
# Data Loader
#   Data:               UEA                 Root Path:          /data/yoom618/TSLib/dataset/AtrialFibrillation/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        /data/yoom618/TSLib/checkpoints
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             200                 Dec In:             7
#   C Out:              0                   d model:            64
#   n heads:            8                   e layers:           1
#   d layers:           1                   d FF:               16
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
# ...

# %% [markdown]
# # Mamba - InsectWingbeat
#
# classification_TV_CLS_InsectWingbeat_MambaSingleLayer_UEA_ftM_sl22_ll0_pl0_dm64_ds3_expand1_dc4_nk4_tvdt1_tvB0_tvC0_Exp_0

# %%
# !python ../run.py \
    --use_gpu True \
    --gpu_type cuda \
    --gpu 1 \
    --task_name classification \
    --data UEA \
    --root_path /data/yoom618/TSLib/dataset/InsectWingbeat \
    --seq_len 78 --enc_in 200 --label_len 0 --pred_len 0 --c_out 0 \
    --checkpoints /data/yoom618/TSLib/checkpoints \
    --model MambaSingleLayer \
    --model_id TV_CLS_InsectWingbeat \
    --d_model 64 --expand 1 --d_conv 4 --tv_dt 1 --tv_B 0 --tv_C 0 \
    --num_kernels 4 --d_ff 3 --is_training 1 --batch_size 16 \
    --des Exp --itr 1 --dropout 0.1 --learning_rate 0.001 --weight_decay 0.0001 --train_epochs 200 --patience 20
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           TV_CLS_InsectWingbeatModel:              MambaSingleLayer
#
# Data Loader
#   Data:               UEA                 Root Path:          /data/yoom618/TSLib/dataset/InsectWingbeat
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        /data/yoom618/TSLib/checkpoints
#
# Model Parameters
#   Top k:              5                   Num Kernels:        4
#   Enc In:             200                 Dec In:             7
#   C Out:              0                   d model:            64
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               3
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
# ...

# %% [markdown]
# # ETSformer - ArticularyWordRecognition
#
# classification_CLS_ArticularyWordRecognition_ETSformer_UEA_ftM_sl144_ll0_pl0_dm512_nh8_el1_dl1_df256_tk4_Exp_0
# classification_CLS_ArticularyWordRecognition_ETSformer_UEA_ftM_sl144_ll0_pl0_dm512_nh8_el1_dl1_df128_tk4_Exp_0

# %%
# !python ../run.py \
  --use_gpu True \
  --gpu_type cuda \
  --gpu 1 \
  --task_name classification \
  --data UEA \
  --root_path /data/yoom618/TSLib/dataset/ArticularyWordRecognition \
  --seq_len 144 \
  --enc_in 9 \
  --label_len 0 \
  --pred_len 0 \
  --c_out 0 \
  --checkpoints /data/yoom618/TSLib/checkpoints \
  --model ETSformer \
  --model_id CLS_ArticularyWordRecognition \
  --e_layers 1 \
  --n_heads 8 \
  --d_model 512 \
  --d_ff 256 \
  --top_k 4 \
  --d_layers 1 \
  --is_training 1 \
  --batch_size 16 \
  --des Exp \
  --itr 1 \
  --dropout 0.1 \
  --learning_rate 0.001 \
  --train_epochs 100 \
  --patience 10
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           CLS_ArticularyWordRecognitionModel:              ETSformer
#
# Data Loader
#   Data:               UEA                 Root Path:          /data/yoom618/TSLib/dataset/ArticularyWordRecognition
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        /data/yoom618/TSLib/checkpoints
#
# Model Parameters
#   Top k:              4                   Num Kernels:        6
#   Enc In:             9                   Dec In:             7
#   C Out:              0                   d model:            512
#   n heads:            8                   e layers:           1
#   d layers:           1                   d FF:               256
#   Moving Avg:         25                  Factor:             1
# ...

# %%
# !python ../run.py \
  --use_gpu True \
  --gpu_type cuda \
  --gpu 1 \
  --task_name classification \
  --data UEA \
  --root_path /data/yoom618/TSLib/dataset/ArticularyWordRecognition \
  --seq_len 144 \
  --enc_in 9 \
  --label_len 0 \
  --pred_len 0 \
  --c_out 0 \
  --checkpoints /data/yoom618/TSLib/checkpoints \
  --model ETSformer \
  --model_id CLS_ArticularyWordRecognition \
  --e_layers 1 \
  --n_heads 8 \
  --d_model 512 \
  --d_ff 128 \
  --top_k 4 \
  --d_layers 1 \
  --is_training 1 \
  --batch_size 16 \
  --des Exp \
  --itr 1 \
  --dropout 0.1 \
  --learning_rate 0.001 \
  --train_epochs 100 \
  --patience 10
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           CLS_ArticularyWordRecognitionModel:              ETSformer
#
# Data Loader
#   Data:               UEA                 Root Path:          /data/yoom618/TSLib/dataset/ArticularyWordRecognition
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        /data/yoom618/TSLib/checkpoints
#
# Model Parameters
#   Top k:              4                   Num Kernels:        6
#   Enc In:             9                   Dec In:             7
#   C Out:              0                   d model:            512
#   n heads:            8                   e layers:           1
#   d layers:           1                   d FF:               128
#   Moving Avg:         25                  Factor:             1
# ...

# %% [markdown]
# # ETSformer - Cricket
#
# classification_CLS_Cricket_ETSformer_UEA_ftM_sl1197_ll0_pl0_dm512_nh8_el1_dl1_df2048_tk4_Exp_0

# %%
# !python ../run.py \
  --use_gpu True \
  --gpu_type cuda \
  --gpu 1 \
  --task_name classification \
  --data UEA \
  --root_path /data/yoom618/TSLib/dataset/Cricket \
  --seq_len 1197 \
  --enc_in 6 \
  --label_len 0 \
  --pred_len 0 \
  --c_out 0 \
  --checkpoints /data/yoom618/TSLib/checkpoints \
  --model ETSformer \
  --model_id CLS_Cricket \
  --e_layers 1 \
  --n_heads 8 \
  --d_model 512 \
  --d_ff 2048 \
  --top_k 4 \
  --d_layers 1 \
  --is_training 1 \
  --batch_size 16 \
  --des Exp \
  --itr 1 \
  --dropout 0.1 \
  --learning_rate 0.001 \
  --train_epochs 100 \
  --patience 10
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           CLS_Cricket         Model:              ETSformer
#
# Data Loader
#   Data:               UEA                 Root Path:          /data/yoom618/TSLib/dataset/Cricket
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        /data/yoom618/TSLib/checkpoints
#
# Model Parameters
#   Top k:              4                   Num Kernels:        6
#   Enc In:             6                   Dec In:             7
#   C Out:              0                   d model:            512
#   n heads:            8                   e layers:           1
#   d layers:           1                   d FF:               2048
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
# ...

# %% [markdown]
# # ETSformer - Epilepsy
#
# classification_CLS_Epilepsy_ETSformer_UEA_ftM_sl206_ll0_pl0_dm256_nh8_el2_dl2_df1024_tk4_Exp_0

# %%
# !python ../run.py \
  --use_gpu True \
  --gpu_type cuda \
  --gpu 1 \
  --task_name classification \
  --data UEA \
  --root_path /data/yoom618/TSLib/dataset/Epilepsy \
  --seq_len 206 \
  --enc_in 3 \
  --label_len 0 \
  --pred_len 0 \
  --c_out 0 \
  --checkpoints /data/yoom618/TSLib/checkpoints \
  --model ETSformer \
  --model_id CLS_Epilepsy \
  --e_layers 2 \
  --n_heads 8 \
  --d_model 256 \
  --d_ff 1024 \
  --top_k 4 \
  --d_layers 2 \
  --is_training 1 \
  --batch_size 16 \
  --des Exp \
  --itr 1 \
  --dropout 0.1 \
  --learning_rate 0.001 \
  --train_epochs 100 \
  --patience 10
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           CLS_Epilepsy        Model:              ETSformer
#
# Data Loader
#   Data:               UEA                 Root Path:          /data/yoom618/TSLib/dataset/Epilepsy
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        /data/yoom618/TSLib/checkpoints
#
# Model Parameters
#   Top k:              4                   Num Kernels:        6
#   Enc In:             3                   Dec In:             7
#   C Out:              0                   d model:            256
#   n heads:            8                   e layers:           2
#   d layers:           2                   d FF:               1024
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
# ...

# %% [markdown]
# # ETSformer - ERing
#
# classification_CLS_ERing_ETSformer_UEA_ftM_sl65_ll0_pl0_dm512_nh8_el2_dl2_df64_tk4_Exp_0

# %%
# !python ../run.py \
  --use_gpu True \
  --gpu_type cuda \
  --gpu 1 \
  --task_name classification \
  --data UEA \
  --root_path /data/yoom618/TSLib/dataset/ERing \
  --seq_len 65 \
  --enc_in 4 \
  --label_len 0 \
  --pred_len 0 \
  --c_out 0 \
  --checkpoints /data/yoom618/TSLib/checkpoints \
  --model ETSformer \
  --model_id CLS_ERing \
  --e_layers 2 \
  --n_heads 8 \
  --d_model 512 \
  --d_ff 64 \
  --top_k 4 \
  --d_layers 2 \
  --is_training 1 \
  --batch_size 16 \
  --des Exp \
  --itr 1 \
  --dropout 0.1 \
  --learning_rate 0.001 \
  --train_epochs 100 \
  --patience 10
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           CLS_ERing           Model:              ETSformer
#
# Data Loader
#   Data:               UEA                 Root Path:          /data/yoom618/TSLib/dataset/ERing
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        /data/yoom618/TSLib/checkpoints
#
# Model Parameters
#   Top k:              4                   Num Kernels:        6
#   Enc In:             4                   Dec In:             7
#   C Out:              0                   d model:            512
#   n heads:            8                   e layers:           2
#   d layers:           2                   d FF:               64
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
# ...

# %% [markdown]
# # ETSformer - Handwriting
#
# classification_CLS_Handwriting_ETSformer_UEA_ftM_sl152_ll0_pl0_dm512_nh8_el2_dl2_df1024_tk1_Exp_0
# classification_CLS_Handwriting_ETSformer_UEA_ftM_sl152_ll0_pl0_dm512_nh8_el2_dl2_df512_tk4_Exp_0
# classification_CLS_Handwriting_ETSformer_UEA_ftM_sl152_ll0_pl0_dm512_nh8_el2_dl2_df512_tk3_Exp_0

# %%
# !python ../run.py \
  --use_gpu True \
  --gpu_type cuda \
  --gpu 1 \
  --task_name classification \
  --data UEA \
  --root_path /data/yoom618/TSLib/dataset/Handwriting \
  --seq_len 152 \
  --enc_in 3 \
  --label_len 0 \
  --pred_len 0 \
  --c_out 0 \
  --checkpoints /data/yoom618/TSLib/checkpoints \
  --model ETSformer \
  --model_id CLS_Handwriting \
  --e_layers 2 \
  --n_heads 8 \
  --d_model 512 \
  --d_ff 1024 \
  --top_k 1 \
  --d_layers 2 \
  --is_training 1 \
  --batch_size 16 \
  --des Exp \
  --itr 1 \
  --dropout 0.1 \
  --learning_rate 0.001 \
  --train_epochs 100 \
  --patience 10
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           CLS_Handwriting     Model:              ETSformer
#
# Data Loader
#   Data:               UEA                 Root Path:          /data/yoom618/TSLib/dataset/Handwriting
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        /data/yoom618/TSLib/checkpoints
#
# Model Parameters
#   Top k:              1                   Num Kernels:        6
#   Enc In:             3                   Dec In:             7
#   C Out:              0                   d model:            512
#   n heads:            8                   e layers:           2
#   d layers:           2                   d FF:               1024
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
# ...

# %%
# !python ../run.py \
  --use_gpu True \
  --gpu_type cuda \
  --gpu 1 \
  --task_name classification \
  --data UEA \
  --root_path /data/yoom618/TSLib/dataset/Handwriting \
  --seq_len 152 \
  --enc_in 3 \
  --label_len 0 \
  --pred_len 0 \
  --c_out 0 \
  --checkpoints /data/yoom618/TSLib/checkpoints \
  --model ETSformer \
  --model_id CLS_Handwriting \
  --e_layers 2 \
  --n_heads 8 \
  --d_model 512 \
  --d_ff 512 \
  --top_k 4 \
  --d_layers 2 \
  --is_training 1 \
  --batch_size 16 \
  --des Exp \
  --itr 1 \
  --dropout 0.1 \
  --learning_rate 0.001 \
  --train_epochs 100 \
  --patience 10
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           CLS_Handwriting     Model:              ETSformer
#
# Data Loader
#   Data:               UEA                 Root Path:          /data/yoom618/TSLib/dataset/Handwriting
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        /data/yoom618/TSLib/checkpoints
#
# Model Parameters
#   Top k:              4                   Num Kernels:        6
#   Enc In:             3                   Dec In:             7
#   C Out:              0                   d model:            512
#   n heads:            8                   e layers:           2
#   d layers:           2                   d FF:               512
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
# ...

# %%
# !python ../run.py \
  --use_gpu True \
  --gpu_type cuda \
  --gpu 1 \
  --task_name classification \
  --data UEA \
  --root_path /data/yoom618/TSLib/dataset/Handwriting \
  --seq_len 152 \
  --enc_in 3 \
  --label_len 0 \
  --pred_len 0 \
  --c_out 0 \
  --checkpoints /data/yoom618/TSLib/checkpoints \
  --model ETSformer \
  --model_id CLS_Handwriting \
  --e_layers 2 \
  --n_heads 8 \
  --d_model 512 \
  --d_ff 512 \
  --top_k 3 \
  --d_layers 2 \
  --is_training 1 \
  --batch_size 16 \
  --des Exp \
  --itr 1 \
  --dropout 0.1 \
  --learning_rate 0.001 \
  --train_epochs 100 \
  --patience 10
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           CLS_Handwriting     Model:              ETSformer
#
# Data Loader
#   Data:               UEA                 Root Path:          /data/yoom618/TSLib/dataset/Handwriting
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        /data/yoom618/TSLib/checkpoints
#
# Model Parameters
#   Top k:              3                   Num Kernels:        6
#   Enc In:             3                   Dec In:             7
#   C Out:              0                   d model:            512
#   n heads:            8                   e layers:           2
#   d layers:           2                   d FF:               512
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
# ...

# %% [markdown]
# # ETSformer - StandWalkJump

# %%
# !python ../run.py \
  --use_gpu True \
  --gpu_type cuda \
  --gpu 1 \
  --task_name classification \
  --data UEA \
  --root_path /data/yoom618/TSLib/dataset/StandWalkJump \
  --seq_len 152 \
  --enc_in 3 \
  --label_len 0 \
  --pred_len 0 \
  --c_out 0 \
  --checkpoints /data/yoom618/TSLib/checkpoints \
  --model ETSformer \
  --model_id CLS_StandWalkJump \
  --e_layers 1 \
  --n_heads 8 \
  --d_model 512 \
  --d_ff 256 \
  --top_k 4 \
  --d_layers 1 \
  --is_training 1 \
  --batch_size 16 \
  --des Exp \
  --itr 1 \
  --dropout 0.1 \
  --learning_rate 0.001 \
  --train_epochs 100 \
  --patience 10
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           CLS_StandWalkJump   Model:              ETSformer
#
# Data Loader
#   Data:               UEA                 Root Path:          /data/yoom618/TSLib/dataset/StandWalkJump
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        /data/yoom618/TSLib/checkpoints
#
# Model Parameters
#   Top k:              4                   Num Kernels:        6
#   Enc In:             3                   Dec In:             7
#   C Out:              0                   d model:            512
#   n heads:            8                   e layers:           1
#   d layers:           1                   d FF:               256
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
# ...
