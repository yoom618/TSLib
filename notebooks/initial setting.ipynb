# %% [markdown]
# ## 필요 라이브러리 설치
#
# - 일단 python 3.12로 실행해봄

# %%
# %pip install --upgrade pip
# %pip install --upgrade setuptools
# Out:
# Requirement already satisfied: pip in /home/yoom618/.local/lib/python3.12/site-packages (25.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: setuptools in /home/yoom618/.local/lib/python3.12/site-packages (75.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

parent_dir = os.path.dirname(os.path.abspath('./'))
os.chdir(parent_dir)
print(parent_dir)
# Out:
# /home/yoom618/TSLib

# %%
# %pip install -r "requirements (no version).txt" --force-reinstall
# %pip cache purge

# !conda update --all --yes
# !conda clean --all --yes
# Out:
# Collecting einops (from -r requirements (no version).txt (line 1))
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting local-attention (from -r requirements (no version).txt (line 2))
#   Downloading local_attention-1.11.1-py3-none-any.whl.metadata (907 bytes)
# Collecting matplotlib (from -r requirements (no version).txt (line 3))
#   Downloading matplotlib-3.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting numpy (from -r requirements (no version).txt (line 4))
#   Using cached numpy-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting pandas (from -r requirements (no version).txt (line 5))
#   Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting patool (from -r requirements (no version).txt (line 6))
#   Downloading patool-3.1.0-py2.py3-none-any.whl.metadata (4.3 kB)
# Collecting reformer-pytorch (from -r requirements (no version).txt (line 7))
#   Downloading reformer_pytorch-1.4.4-py3-none-any.whl.metadata (764 bytes)
# Collecting scikit-learn (from -r requirements (no version).txt (line 8))
#   Using cached scikit_learn-1.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting scipy (from -r requirements (no version).txt (line 9))
#   Using cached scipy-1.15.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting sktime (from -r requirements (no version).txt (line 10))
#   Downloading sktime-0.35.1-py3-none-any.whl.metadata (34 kB)
# Collecting sympy (from -r requirements (no version).txt (line 11))
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting torch (from -r requirements (no version).txt (line 12))
#   Using cached torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting tqdm (from -r requirements (no version).txt (line 13))
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting PyWavelets (from -r requirements (no version).txt (line 14))
#   Downloading pywavelets-1.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting hyper-connections>=0.1.8 (from local-attention->-r requirements (no version).txt (line 2))
#   Downloading hyper_connections-0.1.11-py3-none-any.whl.metadata (5.2 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->-r requirements (no version).txt (line 3))
#   Downloading contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib->-r requirements (no version).txt (line 3))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->-r requirements (no version).txt (line 3))
#   Downloading fonttools-4.55.8-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (101 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->-r requirements (no version).txt (line 3))
#   Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting packaging>=20.0 (from matplotlib->-r requirements (no version).txt (line 3))
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pillow>=8 (from matplotlib->-r requirements (no version).txt (line 3))
#   Using cached pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->-r requirements (no version).txt (line 3))
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting python-dateutil>=2.7 (from matplotlib->-r requirements (no version).txt (line 3))
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas->-r requirements (no version).txt (line 5))
#   Using cached pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->-r requirements (no version).txt (line 5))
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting axial-positional-embedding>=0.1.0 (from reformer-pytorch->-r requirements (no version).txt (line 7))
#   Downloading axial_positional_embedding-0.3.10-py3-none-any.whl.metadata (4.3 kB)
# Collecting product-key-memory (from reformer-pytorch->-r requirements (no version).txt (line 7))
#   Downloading product_key_memory-0.2.11-py3-none-any.whl.metadata (717 bytes)
# Collecting joblib>=1.2.0 (from scikit-learn->-r requirements (no version).txt (line 8))
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->-r requirements (no version).txt (line 8))
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting numpy (from -r requirements (no version).txt (line 4))
#   Using cached numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting scikit-base<0.13.0,>=0.6.1 (from sktime->-r requirements (no version).txt (line 10))
#   Downloading scikit_base-0.12.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting scikit-learn (from -r requirements (no version).txt (line 8))
#   Downloading scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->-r requirements (no version).txt (line 11))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting filelock (from torch->-r requirements (no version).txt (line 12))
#   Using cached filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.10.0 (from torch->-r requirements (no version).txt (line 12))
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting networkx (from torch->-r requirements (no version).txt (line 12))
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch->-r requirements (no version).txt (line 12))
#   Using cached jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch->-r requirements (no version).txt (line 12))
#   Using cached fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->-r requirements (no version).txt (line 12))
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->-r requirements (no version).txt (line 12))
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->-r requirements (no version).txt (line 12))
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->-r requirements (no version).txt (line 12))
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->-r requirements (no version).txt (line 12))
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->-r requirements (no version).txt (line 12))
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->-r requirements (no version).txt (line 12))
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->-r requirements (no version).txt (line 12))
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->-r requirements (no version).txt (line 12))
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch->-r requirements (no version).txt (line 12))
#   Using cached nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch->-r requirements (no version).txt (line 12))
#   Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch->-r requirements (no version).txt (line 12))
#   Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->-r requirements (no version).txt (line 12))
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch->-r requirements (no version).txt (line 12))
#   Using cached triton-3.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting setuptools (from torch->-r requirements (no version).txt (line 12))
#   Using cached setuptools-75.8.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting sympy (from -r requirements (no version).txt (line 11))
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib->-r requirements (no version).txt (line 3))
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->-r requirements (no version).txt (line 12))
#   Using cached MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting colt5-attention>=0.10.14 (from product-key-memory->reformer-pytorch->-r requirements (no version).txt (line 7))
#   Downloading CoLT5_attention-0.11.1-py3-none-any.whl.metadata (737 bytes)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
# Downloading local_attention-1.11.1-py3-none-any.whl (9.4 kB)
# Downloading matplotlib-3.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 10.0 MB/s eta 0:00:0000:0100:01
# Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# Downloading patool-3.1.0-py2.py3-none-any.whl (98 kB)
# Downloading reformer_pytorch-1.4.4-py3-none-any.whl (16 kB)
# Using cached scipy-1.15.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.2 MB)
# Downloading sktime-0.35.1-py3-none-any.whl (36.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.9/36.9 MB 11.1 MB/s eta 0:00:0000:0100:01
# Using cached numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
# Downloading scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 9.7 MB/s eta 0:00:00ta 0:00:01
# Using cached torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl (766.6 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# Using cached nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
# Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Using cached triton-3.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading pywavelets-1.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 9.7 MB/s eta 0:00:00ta 0:00:01
# Downloading axial_positional_embedding-0.3.10-py3-none-any.whl (6.7 kB)
# Downloading contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.8-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 10.9 MB/s eta 0:00:00a 0:00:01
# Downloading hyper_connections-0.1.11-py3-none-any.whl (14 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.9 MB/s eta 0:00:00
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading scikit_base-0.12.0-py3-none-any.whl (141 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Using cached filelock-3.17.0-py3-none-any.whl (16 kB)
# Using cached fsspec-2025.2.0-py3-none-any.whl (184 kB)
# Using cached jinja2-3.1.5-py3-none-any.whl (134 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Downloading product_key_memory-0.2.11-py3-none-any.whl (6.5 kB)
# Using cached setuptools-75.8.0-py3-none-any.whl (1.2 MB)
# Downloading CoLT5_attention-0.11.1-py3-none-any.whl (18 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: triton, pytz, nvidia-cusparselt-cu12, mpmath, tzdata, typing-extensions, tqdm, threadpoolctl, sympy, six, setuptools, scikit-base, pyparsing, pillow, patool, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, kiwisolver, joblib, fsspec, fonttools, filelock, einops, cycler, scipy, PyWavelets, python-dateutil, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, contourpy, scikit-learn, pandas, nvidia-cusolver-cu12, matplotlib, torch, sktime, hyper-connections, axial-positional-embedding, local-attention, colt5-attention, product-key-memory, reformer-pytorch
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.1
#     Uninstalling pytz-2025.1:
#       Successfully uninstalled pytz-2025.1
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.6.2
#     Uninstalling nvidia-cusparselt-cu12-0.6.2:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.6.2
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.1
#     Uninstalling tzdata-2025.1:
#       Successfully uninstalled tzdata-2025.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.5.0
#     Uninstalling threadpoolctl-3.5.0:
#       Successfully uninstalled threadpoolctl-3.5.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.8.0
#     Uninstalling setuptools-75.8.0:
#       Successfully uninstalled setuptools-75.8.0
#   Attempting uninstall: scikit-base
#     Found existing installation: scikit-base 0.12.0
#     Uninstalling scikit-base-0.12.0:
#       Successfully uninstalled scikit-base-0.12.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.2.1
#     Uninstalling pyparsing-3.2.1:
#       Successfully uninstalled pyparsing-3.2.1
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: patool
#     Found existing installation: patool 3.1.0
#     Uninstalling patool-3.1.0:
#       Successfully uninstalled patool-3.1.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.4.127
#     Uninstalling nvidia-nvjitlink-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.5.147
#     Uninstalling nvidia-curand-cu12-10.3.5.147:
#       Successfully uninstalled nvidia-curand-cu12-10.3.5.147
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.1.3
#     Uninstalling nvidia-cufft-cu12-11.2.1.3:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.1.3
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.4.127
#     Uninstalling nvidia-cuda-runtime-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.127
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.4.127
#     Uninstalling nvidia-cuda-cupti-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.4.127
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.4.5.8
#     Uninstalling nvidia-cublas-cu12-12.4.5.8:
#       Successfully uninstalled nvidia-cublas-cu12-12.4.5.8
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.8
#     Uninstalling kiwisolver-1.4.8:
#       Successfully uninstalled kiwisolver-1.4.8
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.9.0
#     Uninstalling fsspec-2024.9.0:
#       Successfully uninstalled fsspec-2024.9.0
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.55.5
#     Uninstalling fonttools-4.55.5:
#       Successfully uninstalled fonttools-4.55.5
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.17.0
#     Uninstalling filelock-3.17.0:
#       Successfully uninstalled filelock-3.17.0
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.0
#     Uninstalling einops-0.8.0:
#       Successfully uninstalled einops-0.8.0
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.1
#     Uninstalling scipy-1.15.1:
#       Successfully uninstalled scipy-1.15.1
#   Attempting uninstall: PyWavelets
#     Found existing installation: PyWavelets 1.8.0
#     Uninstalling PyWavelets-1.8.0:
#       Successfully uninstalled PyWavelets-1.8.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.3.1.170
#     Uninstalling nvidia-cusparse-cu12-12.3.1.170:
#       Successfully uninstalled nvidia-cusparse-cu12-12.3.1.170
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.5
#     Uninstalling Jinja2-3.1.5:
#       Successfully uninstalled Jinja2-3.1.5
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.3.1
#     Uninstalling contourpy-1.3.1:
#       Successfully uninstalled contourpy-1.3.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.1.9
#     Uninstalling nvidia-cusolver-cu12-11.6.1.9:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.1.9
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0
#     Uninstalling torch-2.6.0:
#       Successfully uninstalled torch-2.6.0
#   Attempting uninstall: sktime
#     Found existing installation: sktime 0.35.0
#     Uninstalling sktime-0.35.0:
#       Successfully uninstalled sktime-0.35.0
#   Attempting uninstall: hyper-connections
#     Found existing installation: hyper-connections 0.1.9
#     Uninstalling hyper-connections-0.1.9:
#       Successfully uninstalled hyper-connections-0.1.9
#   Attempting uninstall: axial-positional-embedding
#     Found existing installation: axial_positional_embedding 0.3.10
#     Uninstalling axial_positional_embedding-0.3.10:
#       Successfully uninstalled axial_positional_embedding-0.3.10
#   Attempting uninstall: local-attention
#     Found existing installation: local-attention 1.11.1
#     Uninstalling local-attention-1.11.1:
#       Successfully uninstalled local-attention-1.11.1
#   Attempting uninstall: colt5-attention
#     Found existing installation: CoLT5-attention 0.11.1
#     Uninstalling CoLT5-attention-0.11.1:
#       Successfully uninstalled CoLT5-attention-0.11.1
#   Attempting uninstall: product-key-memory
#     Found existing installation: product_key_memory 0.2.11
#     Uninstalling product_key_memory-0.2.11:
#       Successfully uninstalled product_key_memory-0.2.11
#   Attempting uninstall: reformer-pytorch
#     Found existing installation: reformer-pytorch 1.4.4
#     Uninstalling reformer-pytorch-1.4.4:
#       Successfully uninstalled reformer-pytorch-1.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.2.0 requires fsspec[http]<=2024.9.0,>=2023.1.0, but you have fsspec 2025.2.0 which is incompatible.
# Successfully installed MarkupSafe-3.0.2 PyWavelets-1.8.0 axial-positional-embedding-0.3.10 colt5-attention-0.11.1 contourpy-1.3.1 cycler-0.12.1 einops-0.8.0 filelock-3.17.0 fonttools-4.55.8 fsspec-2024.12.0 hyper-connections-0.1.9 jinja2-3.1.5 joblib-1.4.2 kiwisolver-1.4.8 local-attention-1.11.1 matplotlib-3.10.0 mpmath-1.3.0 networkx-3.4.2 numpy-2.1.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 packaging-24.2 pandas-2.2.3 patool-3.1.0 pillow-11.1.0 product-key-memory-0.2.11 pyparsing-3.2.1 python-dateutil-2.9.0.post0 pytz-2025.1 reformer-pytorch-1.4.4 scikit-base-0.12.0 scikit-learn-1.5.2 scipy-1.15.1 setuptools-75.8.0 six-1.17.0 sktime-0.35.1 sympy-1.13.1 threadpoolctl-3.5.0 torch-2.5.1 tqdm-4.67.1 triton-3.2.0 typing-extensions-4.12.2 tzdata-2025.1
# Note: you may need to restart the kernel to use updated packages.
# Files removed: 796 (3912.9 MB)
# Note: you may need to restart the kernel to use updated packages.
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/yoom618/.conda/envs/tslib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pip-25.0                   |  py312h06a4308_0         2.8 MB
#     setuptools-75.8.0          |  py312h06a4308_0         2.2 MB
#     wheel-0.45.1               |  py312h06a4308_0         147 KB
#     ------------------------------------------------------------
#                                            Total:         5.1 MB
#
# The following packages will be UPDATED:
#
#   pip                                  24.2-py312h06a4308_0 --> 25.0-py312h06a4308_0
#   setuptools                         75.1.0-py312h06a4308_0 --> 75.8.0-py312h06a4308_0
#   wheel                              0.44.0-py312h06a4308_0 --> 0.45.1-py312h06a4308_0
#
#
#
# Downloading and Extracting Packages:
# pip-25.0             | 2.8 MB    |                                       |   0%
# setuptools-75.8.0    | 2.2 MB    |                                       |   0%
#
# wheel-0.45.1         | 147 KB    |                                       |   0%
#
# pip-25.0             | 2.8 MB    | ####5                                 |  12%
# setuptools-75.8.0    | 2.2 MB    | #                                     |   3%
#
# wheel-0.45.1         | 147 KB    | ##################################### | 100%
#
# wheel-0.45.1         | 147 KB    | ##################################### | 100%
# pip-25.0             | 2.8 MB    | #########6                            |  26%
# pip-25.0             | 2.8 MB    | #######################3              |  63%
# pip-25.0             | 2.8 MB    | ################################2     |  87%
# setuptools-75.8.0    | 2.2 MB    | ##################################### | 100%
# pip-25.0             | 2.8 MB    | ##################################### | 100%
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Will remove 22 (7.6 MB) tarball(s).
# Will remove 1 index cache(s).
# Will remove 6 (44.5 MB) package(s).
# There are no tempfile(s) to remove.
# There are no logfile(s) to remove.

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.6.0
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3-Clause
# Location: /home/yoom618/.local/lib/python3.12/site-packages
# Requires: filelock, fsspec, jinja2, networkx, nvidia-cublas-cu12, nvidia-cuda-cupti-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-runtime-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, nvidia-curand-cu12, nvidia-cusolver-cu12, nvidia-cusparse-cu12, nvidia-cusparselt-cu12, nvidia-nccl-cu12, nvidia-nvjitlink-cu12, nvidia-nvtx-cu12, setuptools, sympy, triton, typing-extensions
# Required-by: accelerate, axial_positional_embedding, causal_conv1d, CoLT5-attention, hyper-connections, lightning, local-attention, mamba_ssm, product_key_memory, pytorch-lightning, reformer-pytorch, torchaudio, torchmetrics, torchvision

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## 데이터셋 다운

# %%
# !unzip -q -o "all_datasets.zip" -d "."
# !mv "all_datasets" "dataset"

# %%
# !ls dataset -alh
# Out:
# total 104K
# drwxr-xr-x 24 yoom618 yoom618 4.0K Feb 11  2023 .
# drwxr-xr-x 15 yoom618 yoom618 4.0K Jan 24 20:25 ..
# -rw-r--r--  1 yoom618 yoom618 6.1K Feb 11  2023 .DS_Store
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 electricity
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 EthanolConcentration
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 ETT-small
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 exchange_rate
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 FaceDetection
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 Handwriting
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 Heartbeat
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 illness
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 JapaneseVowels
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 m4
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 MSL
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 PEMS-SF
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 PSM
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 SelfRegulationSCP1
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 SelfRegulationSCP2
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 SMAP
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 SMD
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 SpokenArabicDigits
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 SWaT
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 traffic
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 UWaveGestureLibrary
# drwxr-xr-x  2 yoom618 yoom618 4.0K Feb 11  2023 weather
